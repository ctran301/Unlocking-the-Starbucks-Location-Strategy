# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
csv_path = "Starbucks Locations Data.csv"
global_df = pd.read_csv(csv_path)
global_df.head()
# Out:
#        Brand Ownership Type              City State/Province Country  \
# 0  Starbucks       Licensed  Andorra la Vella              7      AD
# 1  Starbucks       Licensed             Ajman             AJ      AE
# 2  Starbucks       Licensed             Ajman             AJ      AE
# 3  Starbucks       Licensed         Abu Dhabi             AZ      AE
# 4  Starbucks       Licensed         Abu Dhabi             AZ      AE
#
#    Longitude  Latitude Continent  Zip Code
# 0       1.53     42.51    Europe       NaN
# 1      55.47     25.42      Asia       NaN
# 2      55.47     25.39      Asia       NaN
# 3      54.38     24.48      Asia       NaN
# 4      54.54     24.51      Asia       NaN

# %%
continent_df = global_df.groupby(["Continent"]).agg({'Ownership Type':'count'})


continent_df = continent_df.head(10)

continent_df.reset_index(inplace=True)

continent_df
# Out:
#        Continent  Ownership Type
# 0         Africa              43
# 1           Asia            7486
# 2         Europe            1883
# 3  North America           15381
# 4        Oceania              46
# 5  South America             410

# %%
explode = [0,0,0,0,0,0]
plt.figure(figsize=(30,15))
# plot chart
ax1 = plt.subplot(aspect='equal')
continent_df.plot(kind='pie', y = 'Ownership Type', labels=continent_df['Continent'], ax=ax1, autopct='%1.0f%%', pctdistance = 1.05, rotatelabels=90, explode = explode,
            startangle=90, fontsize=12)
ax1.set_ylabel('')
ax1.set_title('Global Starbucks Locations', y=1.1, fontsize = 15)
# Out:
# Text(0.5,1.1,'Global Starbucks Locations')
